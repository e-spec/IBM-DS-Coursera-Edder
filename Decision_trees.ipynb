# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
#
# # Decision Trees
#
#
# Estimated time needed: **25** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Develop a classification model using Decision Tree Algorithm
# * Apply Decision Tree classification on a real world dataset.

# %% [markdown]
# ## Introduction
#
# This lab explores decision tree classification, a powerful machine learning technique for making data-driven decisions. You will learn to build, visualize, and evaluate decision trees using a real-world dataset. The dataset used in this lab is that of Drug prediction based on the health parameters of a patient.

# %% [markdown]
# ### Importing Libraries
# First, to make sure that the required libraries are available, execute the cell below.

# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
print('Install Ready')
# Out:
# Requirement already satisfied: numpy==2.2.0 in c:\users\admin\anaconda3\lib\site-packages (2.2.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# Requirement already satisfied: pandas==2.2.3 in c:\users\admin\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas==2.2.3) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# Collecting scikit-learn==1.6.0
#   Using cached scikit_learn-1.6.0-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (3.6.0)
# Using cached scikit_learn-1.6.0-cp313-cp313-win_amd64.whl (11.1 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.8.0
#     Uninstalling scikit-learn-1.8.0:
#       Successfully uninstalled scikit-learn-1.8.0
# Successfully installed scikit-learn-1.6.0
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# Requirement already satisfied: matplotlib==3.9.3 in c:\users\admin\anaconda3\lib\site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
# Install Ready
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\anaconda3\Lib\site-packages)

# %% [markdown]
# Now import the required libraries for this lab.

# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import metrics

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

print('Imports Ready')
# Out:
# Imports Ready

# %% [markdown]
# ### About the dataset
# Imagine that you are a medical researcher compiling data for a study. You have collected data about a set of patients, all of whom suffered from the same illness. During their course of treatment, each patient responded to one of 5 medications, Drug A, Drug B, Drug C, Drug X and Drug Y.
#
# Part of your job is to build a model to find out which drug might be appropriate for a future patient with the same illness. The features of this dataset are the Age, Sex, Blood Pressure, and Cholesterol of the patients, and Sodium to potassium ratio in blood and the target is the drug that each patient responded to.
#
# It is a sample of a multiclass classifier, and you can use the training part of the dataset to build a decision tree, and then use it to predict the class of an unknown patient or to prescribe a drug to a new patient.

# %% [markdown]
# <div id="downloading_data">
#     <h2>Downloading the Data</h2>
#     To download the data, we will use !wget to download it from IBM Object Storage.
# </div>

# %%
path= 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/drug200.csv'
my_data = pd.read_csv(path)
my_data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %% [markdown]
# ## Data Analysis and pre-processing
# You should apply some basic analytics steps to understand the data better. First, let us gather some basic information about the dataset.

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# This tells us that 4 out of the 6 features of this dataset are categorical, which will have to be converted into numerical ones to be used for modeling. For this, we can make use of __LabelEncoder__ from the Scikit-Learn library.

# %%
#Label Encoder: convert categorical features in the DataFrame my_data into numerical values
label_encoder = LabelEncoder()
my_data['Sex'] = label_encoder.fit_transform(my_data['Sex']) 
my_data['BP'] = label_encoder.fit_transform(my_data['BP'])
my_data['Cholesterol'] = label_encoder.fit_transform(my_data['Cholesterol']) 
my_data
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   0            0   25.355  drugY
# 1     47    1   1            0   13.093  drugC
# 2     47    1   1            0   10.114  drugC
# 3     28    0   2            0    7.798  drugX
# 4     61    0   1            0   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   1            0   11.567  drugC
# 196   16    1   1            0   12.006  drugC
# 197   52    1   2            0    9.894  drugX
# 198   23    1   2            1   14.020  drugX
# 199   40    0   1            1   11.349  drugX
#
# [200 rows x 6 columns]

# %% [markdown]
# With this, you now have 5 parameters that can be used for modeling and 1 feature as the target variable.
# We can see from comparison of the data before Label encoding and after it, to note the following mapping.
# <br>
# For parameter 'Sex' : $M \rightarrow 1, F \rightarrow 0$ <br>
# For parameter 'BP' : $High \rightarrow 0, Low \rightarrow 1, Normal \rightarrow 2$<br>
# For parameter 'Cholesterol' : $High \rightarrow 0, Normal \rightarrow 1$

# %% [markdown]
# You can also check if there are any missing values in the dataset.

# %%
my_data.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %% [markdown]
# This tells us that there are no missing values in any of the fields.

# %% [markdown]
# To evaluate the correlation of the target variable with the input features, it will be convenient to map the different drugs to a numerical value. Execute the following cell to achieve the same.

# %%
custom_map = {'drugA':0,'drugB':1,'drugC':2,'drugX':3,'drugY':4}

#maps the categorical values in the 'Drug' column to their corresponding numerical values using the map() function
my_data['Drug_num'] = my_data['Drug'].map(custom_map)
my_data

# my_data['Drug_num'] = my_data['Drug']
# label_encoder2 = LabelEncoder()
# my_data['Drug_num'] = label_encoder2.fit_transform(my_data['Drug_num']) 
# my_data
# my_data['Drug_num'].unique()
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug  Drug_num
# 0     23    0   0            0   25.355  drugY         4
# 1     47    1   1            0   13.093  drugC         2
# 2     47    1   1            0   10.114  drugC         2
# 3     28    0   2            0    7.798  drugX         3
# 4     61    0   1            0   18.043  drugY         4
# ..   ...  ...  ..          ...      ...    ...       ...
# 195   56    0   1            0   11.567  drugC         2
# 196   16    1   1            0   12.006  drugC         2
# 197   52    1   2            0    9.894  drugX         3
# 198   23    1   2            1   14.020  drugX         3
# 199   40    0   1            1   11.349  drugX         3
#
# [200 rows x 7 columns]

# %% [markdown]
# You can now use the __corr()__ function to find the correlation of the input variables with the target variable.
#
# #### Practice question
# Write the code to find the correlation of the input variables with the target variable and identify the features most significantly affecting the target.

# %%
# Drop the Drug column from my_data
my_data_dropped = my_data.drop('Drug', axis=1)

# Calculate correlation matrix
correlation_matrix = my_data_dropped.corr()
correlation_matrix
# Out:
#                   Age       Sex        BP  Cholesterol   Na_to_K  Drug_num
# Age          1.000000  0.102027  0.054212    -0.068234 -0.063119 -0.004828
# Sex          0.102027  1.000000 -0.007814    -0.008811 -0.125008 -0.098573
# BP           0.054212 -0.007814  1.000000    -0.137552 -0.149312  0.372868
# Cholesterol -0.068234 -0.008811 -0.137552     1.000000  0.010000  0.055629
# Na_to_K     -0.063119 -0.125008 -0.149312     0.010000  1.000000  0.589120
# Drug_num    -0.004828 -0.098573  0.372868     0.055629  0.589120  1.000000

# %% [markdown]
# # your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# my_data.drop('Drug',axis=1).corr()['Drug_num']
# ```
#
# This shows that the drug recommendation is mostly correlated with the `Na_to_K` and `BP` features.
#
# </details>

# %% [markdown]
# We can also understand the distribution of the dataset by plotting the count of the records with each drug recommendation.

# %%
category_counts = my_data['Drug'].value_counts()

category_counts
# Add value labels on top of each bar
for i, value in enumerate(category_counts.values):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# Plot the count plot
plt.bar(category_counts.index, category_counts.values)#, color='blue')
plt.xlabel('Drug')
plt.ylabel('Count')
plt.title('Category Distribution')
plt.xticks(rotation=45)  # Rotate labels for better readability if needed
plt.show()

# %% [markdown]
# This shows us the distribution of the different classes, clearly indicating that Drug X and Drug Y have many more records in comparison to the other 3.

# %% [markdown]
# ## Modeling

# %% [markdown]
# For modeling this dataset with a Decision tree classifier, we first split the dataset into training and testing subsets. For this, we separate the target variable from the input variables.

# %%
y = my_data['Drug']
X = my_data.drop(['Drug','Drug_num'], axis=1)

print(X.iloc[0:5])
print('   ')
print(y.iloc[0:5])
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K
# 0   23    0   0            0   25.355
# 1   47    1   1            0   13.093
# 2   47    1   1            0   10.114
# 3   28    0   2            0    7.798
# 4   61    0   1            0   18.043
#
# 0    drugY
# 1    drugC
# 2    drugC
# 3    drugX
# 4    drugY
# Name: Drug, dtype: object

# %% [markdown]
# Now, use the __train_test_split()__ function to separate the training data from the testing data. We can make use of 30% of the data for testing and the rest for training the Decision tree.

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=32)

# %% [markdown]
# You can now define the Decision tree classifier as __drugTree__ and train it with the training data.

# %%
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)

# %%
#When you call get_params() on a decision tree classifier (or any other estimator), 
#it returns a dictionary of the parameters and their current values.
drugTree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
drugTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Now that you have trained the decision tree, we can use it to generate the predictions on the test set.

# %%
tree_predictions = drugTree.predict(X_testset)

# %% [markdown]
# We can now check the accuracy of our model by using the accuracy metric.

# %%
print("Decision Trees's Accuracy: ", metrics.accuracy_score(y_testset, tree_predictions))
# Out:
# Decision Trees's Accuracy:  0.9833333333333333

# %% [markdown]
# This means that the model was able to correctly identify the labels of 98.33%, i.e. 59 out of 60 test samples.

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_testset,tree_predictions))
#Rows correspond to the actual classes.
#Columns correspond to the predicted classes.
#eg: Row 1 (Actual Class 1): 
#8 instances correctly classified as Class 1.
#0 instances misclassified as Classes 2, 3, 4, or 5.
# Out:
# [[ 8  0  0  0  0]
#  [ 0  5  0  0  0]
#  [ 0  0  3  0  0]
#  [ 0  0  0 15  1]
#  [ 0  0  0  0 28]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_testset,tree_predictions))
#The classification report provides a detailed breakdown of your model's performance.
#Precision: It tells us how many of the predicted positive instances are actually correct.
#Recall: It tells us how many of the actual positive instances are correctly identified by the model.
#F1-Score: It provides a balance between precision and recall, giving an overall performance metric for the model.
#Support: Support is the number of actual occurrences of each class in the dataset.

#Accuracy: 0.82 (82% of the total instances were correctly classified)
# Out:
#               precision    recall  f1-score   support
#
#        drugA       1.00      1.00      1.00         8
#        drugB       1.00      1.00      1.00         5
#        drugC       1.00      1.00      1.00         3
#        drugX       1.00      0.94      0.97        16
#        drugY       0.97      1.00      0.98        28
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.99      0.99        60
# weighted avg       0.98      0.98      0.98        60

# %% [markdown]
# ### Visualize the tree
#
# To understand the classification criteria derived by the Decision Tree, we may generate the tree plot.

# %%
plot_tree(drugTree)
plt.show()

# %% [markdown]
# From this tree, we can derive the criteria developed by the model to identify the class of each training sample. We can interpret them by tracing the criteria defined by tracing down from the root to the tree's leaf nodes.
#
# For instance, the decision criterion for Drug Y is ${Na\_to\_K} \gt 14.627$.
#
# #### Practice Question:
# Along similar lines, identify the decision criteria for all other classes.

# %% [markdown]
# <details><summary>Click here for the solution</summary>
# Drug A : $Na\_to\_K <= 14.627, BP = High, Age <= 50.5$<br>
# Drug B : $Na\_to\_K <= 14.627, BP = High, Age > 50.5$ <br>
# Drug C : $Na\_to\_K <= 14.627, BP = Normal, Cholesterol = High$<br>
# Drug X : $Na\_to\_K <= 14.627, (BP = Low, Cholesterol = High) or (BP = Normal/Low, Cholesterol = Normal)$
# </details>

# %% [markdown]
# #### Practice Question:
#
# If the max depth of the tree is reduced to 3, how would the performance of the model be affected?

# %%
# your code here
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 2)
drugTree.fit(X_trainset,y_trainset)
tree_predictions = drugTree.predict(X_testset)
print("Decision Trees's Accuracy: ", metrics.accuracy_score(y_testset, tree_predictions))

from sklearn.metrics import classification_report
print(classification_report(y_testset,tree_predictions))
# Out:
# Decision Trees's Accuracy:  0.85
#               precision    recall  f1-score   support
#
#        drugA       0.62      1.00      0.76         8
#        drugB       0.00      0.00      0.00         5
#        drugC       0.00      0.00      0.00         3
#        drugX       0.83      0.94      0.88        16
#        drugY       0.97      1.00      0.98        28
#
#     accuracy                           0.85        60
#    macro avg       0.48      0.59      0.53        60
# weighted avg       0.75      0.85      0.80        60

# %%
plot_tree(drugTree)
plt.show()

# %%
custom_map
# Out:
# {'drugA': 0, 'drugB': 1, 'drugC': 2, 'drugX': 3, 'drugY': 4}

# %% [markdown]
# Drug4=DrugY-->At the root node, the tree splits based on whether the feature value X[4]=𝑁𝑎_𝑡𝑜_𝐾 is less than or equal to 14.627
#
# Left Child (of Root Node):
# For samples that satisfy X[4]=𝑁𝑎_𝑡𝑜_𝐾 <= 14.627, the next split is based on X[2]=BP <= 0.5.
#
# Right Child (of Root Node):
# For samples that do not satisfy X[4]=𝑁𝑎_𝑡𝑜_𝐾 <= 14.627, all samples belong to the fifth class with no impurity (entropy = 0.0).
#
# Left Child of X[2] <= 0.5:
# If both X[4] <= 14.627 and X[2] <= 0.5 are satisfied, the tree splits further based on X[0] <= 50.5.
#
# Right Child of X[2] <= 0.5:
# All samples are classified into the second class with no impurity.

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 3)
# drugTree.fit(X_trainset,y_trainset)
# tree_predictions = drugTree.predict(X_testset)
# print("Decision Trees's Accuracy: ", metrics.accuracy_score(y_testset, tree_predictions))
# ```
#
# </details>

# %% [markdown]
# ### Congratulations! You're ready to move on to your next lesson!
#
# ## Author
# <a href="https://www.linkedin.com/in/abhishek-gagneja-23051987/" target="_blank">Abhishek Gagneja</a>
# ### Other Contributors
# <a href="https://www.linkedin.com/in/jpgrossman/" target="_blank">Jeff Grossman</a>
#
# <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>
#
#
# <!--
# ## Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version       | Changed By     | Change Description                  |
# |---|---|---|---|
# | 2024-10-31         | 3.0            | Abhishek Gagneja  | Rewrite                             |
# | 2020-11-03         | 2.1            | Lakshmi        | Made changes in URL                 |
# | 2020-11-03         | 2.1            | Lakshmi        | Made changes in URL                 |
# | 2020-08-27         | 2.0            | Lavanya        | Moved lab to course repo in GitLab  |
# |   |   |   |   |
