# %%
d = {'key1': {'a': 5, 'c': 90, 5: 50}, 'key2':{'b': 3, 'c': "yes"}}

# %%
d
# Out:
# {'key1': {'a': 5, 'c': 90, 5: 50}, 'key2': {'b': 3, 'c': 'yes'}}

# %%
info = {'personal_data':
         {'name': 'Lauren',
          'age': 20,
          'major': 'Information Science',
          'physical_features':
             {'color': {'eye': 'blue',
                        'hair': 'brown'},
              'height': "5'8"}
         },
       'other':
         {'favorite_colors': ['purple', 'green', 'blue'],
          'interested_in': ['social media', 'intellectual property', 'copyright', 'music', 'books']
         }
      }

# %%
info
# Out:
# {'personal_data': {'name': 'Lauren',
#   'age': 20,
#   'major': 'Information Science',
#   'physical_features': {'color': {'eye': 'blue', 'hair': 'brown'},
#    'height': "5'8"}},
#  'other': {'favorite_colors': ['purple', 'green', 'blue'],
#   'interested_in': ['social media',
#    'intellectual property',
#    'copyright',
#    'music',
#    'books']}}

# %%
# Access the nested dictionary to extract the value associated with the key 'color'
color = info['personal_data']['physical_features']['color']

# Print the value of the variable color
print(color)
# Out:
# {'eye': 'blue', 'hair': 'brown'}
